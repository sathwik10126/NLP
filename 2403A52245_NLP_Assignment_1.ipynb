# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwik10126/NLP/blob/Main/2403A52245_NLP_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
pip install spacy

# %%
import nltk
import spacy
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# The text contains 51 words.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
text_data = """Entrepreneurship is the creation or extraction of
               economic value by identifying and commercializing opportunities
               to deliver innovative products or services; a process that
               typically requires considerable initiative and bears risk.[1]
               This process may also encompass the pursuit of values that extend
               beyond mere economic considerations."""

# %%
words=text_data.split()
word_count=len(words)
print("no of words:",word_count)
# Out:
# no of words 45
# ['Entrepreneurship', 'is', 'the', 'creation', 'or', 'extraction', 'of', 'economic', 'value', 'by', 'identifying', 'and', 'commercializing', 'opportunities', 'to', 'deliver', 'innovative', 'products', 'or', 'services;', 'a', 'process', 'that', 'typically', 'requires', 'considerable', 'initiative', 'and', 'bears', 'risk.[1]', 'This', 'process', 'may', 'also', 'encompass', 'the', 'pursuit', 'of', 'values', 'that', 'extend', 'beyond', 'mere', 'economic', 'considerations.']

# %%
lowercase_text = text_data.lower()

print("Original text (first 200 chars):")
print(text_data[:200])
print("\nLowercase text (first 200 chars):")
print(lowercase_text[:200])
# Out:
# Original text (first 200 chars):
# Entrepreneurship is the creation or extraction of
#                economic value by identifying and commercializing opportunities
#                to deliver innovative products or services; a process t
#
# Lowercase text (first 200 chars):
# entrepreneurship is the creation or extraction of
#                economic value by identifying and commercializing opportunities
#                to deliver innovative products or services; a process t

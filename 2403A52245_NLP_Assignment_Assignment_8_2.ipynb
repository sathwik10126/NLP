# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwik10126/NLP/blob/Main/2403A52245_NLP_Assignment_Assignment_8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Corpus**

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/tech_documents.csv")

# %%
display(data)
# Out:
#   Document                                               Text
# 0       D1  I am studying B.Tech in Computer Science at SR...
# 1       D2  I am learning programming, data structures, an...
# 2       D3  I completed my intermediate education in MPC w...
# 3       D4  I want to become a software engineer and build...
# 4       D5  I am improving my coding skills by practicing ...
# 5       D6  I am exploring artificial intelligence and dee...
# 6       D7  I participate in technical workshops and semin...
# 7       D8  I enjoy working on real-world software develop...
# 8       D9  I aim to contribute to modern technology throu...
# 9      D10  I am preparing for a successful career in the ...

# %% [markdown]
# # **Uni Gram Counts**

# %%
import collections


# Combine the text from D1, D2, D3, D4 (using the newly defined content variables)


# Tokenize the combined text into words and convert to lowercase
# Corrected line to handle DataFrame 'data'
words = ' '.join(data['Text'].astype(str)).lower().split()

# Calculate unigram counts
unigram_counts = collections.Counter(words)

# Print the unigram counts
print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
#Vocabulary size is length of unigrams
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# i: 10
# in: 6
# am: 5
# and: 5
# my: 5
# to: 4
# learning: 3
# b.tech: 2
# a: 2
# software: 2
# technology: 2
# studying: 1
# computer: 1
# science: 1
# at: 1
# sr: 1
# university.: 1
# programming,: 1
# data: 1
# structures,: 1
# machine: 1
# during: 1
# course.: 1
# completed: 1
# intermediate: 1
# education: 1
# mpc: 1
# with: 1
# strong: 1
# interest: 1
# mathematics.: 1
# want: 1
# become: 1
# engineer: 1
# build: 1
# innovative: 1
# solutions.: 1
# improving: 1
# coding: 1
# skills: 1
# by: 1
# practicing: 1
# problems: 1
# every: 1
# day.: 1
# exploring: 1
# artificial: 1
# intelligence: 1
# deep: 1
# concepts: 1
# studies.: 1
# participate: 1
# technical: 1
# workshops: 1
# seminars: 1
# enhance: 1
# knowledge.: 1
# enjoy: 1
# working: 1
# on: 1
# real-world: 1
# development: 1
# projects.: 1
# aim: 1
# contribute: 1
# modern: 1
# through: 1
# research: 1
# innovation.: 1
# preparing: 1
# for: 1
# successful: 1
# career: 1
# the: 1
# it: 1
# industry.: 1
# Vocabulary Size= 76

# %% [markdown]
# # **Bi-Gram Counts**

# %%
import collections

# Tokenize the combined text into words and convert to lowercase
# Corrected line to handle DataFrame 'data'
words = ' '.join(data['Text'].astype(str)).lower().split()

# Generate bigrams
bigrams = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Calculate bigram counts
bigram_counts = collections.Counter(bigrams)

# Print the bigram counts
print("Bi-gram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram}: {count}")

# Vocabulary size is length of bigrams
V_bigrams = len(bigram_counts)
print("Bigram Vocabulary Size=", V_bigrams)
# Out:
# Bi-gram Counts:
# ('i', 'am'): 5
# ('am', 'studying'): 1
# ('studying', 'b.tech'): 1
# ('b.tech', 'in'): 1
# ('in', 'computer'): 1
# ('computer', 'science'): 1
# ('science', 'at'): 1
# ('at', 'sr'): 1
# ('sr', 'university.'): 1
# ('university.', 'i'): 1
# ('am', 'learning'): 1
# ('learning', 'programming,'): 1
# ('programming,', 'data'): 1
# ('data', 'structures,'): 1
# ('structures,', 'and'): 1
# ('and', 'machine'): 1
# ('machine', 'learning'): 1
# ('learning', 'during'): 1
# ('during', 'my'): 1
# ('my', 'b.tech'): 1
# ('b.tech', 'course.'): 1
# ('course.', 'i'): 1
# ('i', 'completed'): 1
# ('completed', 'my'): 1
# ('my', 'intermediate'): 1
# ('intermediate', 'education'): 1
# ('education', 'in'): 1
# ('in', 'mpc'): 1
# ('mpc', 'with'): 1
# ('with', 'strong'): 1
# ('strong', 'interest'): 1
# ('interest', 'in'): 1
# ('in', 'mathematics.'): 1
# ('mathematics.', 'i'): 1
# ('i', 'want'): 1
# ('want', 'to'): 1
# ('to', 'become'): 1
# ('become', 'a'): 1
# ('a', 'software'): 1
# ('software', 'engineer'): 1
# ('engineer', 'and'): 1
# ('and', 'build'): 1
# ('build', 'innovative'): 1
# ('innovative', 'technology'): 1
# ('technology', 'solutions.'): 1
# ('solutions.', 'i'): 1
# ('am', 'improving'): 1
# ('improving', 'my'): 1
# ('my', 'coding'): 1
# ('coding', 'skills'): 1
# ('skills', 'by'): 1
# ('by', 'practicing'): 1
# ('practicing', 'problems'): 1
# ('problems', 'every'): 1
# ('every', 'day.'): 1
# ('day.', 'i'): 1
# ('am', 'exploring'): 1
# ('exploring', 'artificial'): 1
# ('artificial', 'intelligence'): 1
# ('intelligence', 'and'): 1
# ('and', 'deep'): 1
# ('deep', 'learning'): 1
# ('learning', 'concepts'): 1
# ('concepts', 'in'): 1
# ('in', 'my'): 1
# ('my', 'studies.'): 1
# ('studies.', 'i'): 1
# ('i', 'participate'): 1
# ('participate', 'in'): 1
# ('in', 'technical'): 1
# ('technical', 'workshops'): 1
# ('workshops', 'and'): 1
# ('and', 'seminars'): 1
# ('seminars', 'to'): 1
# ('to', 'enhance'): 1
# ('enhance', 'my'): 1
# ('my', 'knowledge.'): 1
# ('knowledge.', 'i'): 1
# ('i', 'enjoy'): 1
# ('enjoy', 'working'): 1
# ('working', 'on'): 1
# ('on', 'real-world'): 1
# ('real-world', 'software'): 1
# ('software', 'development'): 1
# ('development', 'projects.'): 1
# ('projects.', 'i'): 1
# ('i', 'aim'): 1
# ('aim', 'to'): 1
# ('to', 'contribute'): 1
# ('contribute', 'to'): 1
# ('to', 'modern'): 1
# ('modern', 'technology'): 1
# ('technology', 'through'): 1
# ('through', 'research'): 1
# ('research', 'and'): 1
# ('and', 'innovation.'): 1
# ('innovation.', 'i'): 1
# ('am', 'preparing'): 1
# ('preparing', 'for'): 1
# ('for', 'a'): 1
# ('a', 'successful'): 1
# ('successful', 'career'): 1
# ('career', 'in'): 1
# ('in', 'the'): 1
# ('the', 'it'): 1
# ('it', 'industry.'): 1
# Bigram Vocabulary Size= 106

# %% [markdown]
# ### **Tri-Gram Counts**

# %%
import collections


words = ' '.join(data['Text'].astype(str)).lower().split()


Trigrams = []
for i in range(len(words) - 2):
    Trigrams.append((words[i], words[i+1], words[i+2]))

Trigrams_counts = collections.Counter(Trigrams)

print("\nTrigrams Counts:")
for Trigrams, count in Trigrams_counts.most_common():
    print(f"{Trigrams}: {count}")
# Out:
# Trigrams Counts:
# ('i', 'am', 'studying'): 1
# ('am', 'studying', 'b.tech'): 1
# ('studying', 'b.tech', 'in'): 1
# ('b.tech', 'in', 'computer'): 1
# ('in', 'computer', 'science'): 1
# ('computer', 'science', 'at'): 1
# ('science', 'at', 'sr'): 1
# ('at', 'sr', 'university.'): 1
# ('sr', 'university.', 'i'): 1
# ('university.', 'i', 'am'): 1
# ('i', 'am', 'learning'): 1
# ('am', 'learning', 'programming,'): 1
# ('learning', 'programming,', 'data'): 1
# ('programming,', 'data', 'structures,'): 1
# ('data', 'structures,', 'and'): 1
# ('structures,', 'and', 'machine'): 1
# ('and', 'machine', 'learning'): 1
# ('machine', 'learning', 'during'): 1
# ('learning', 'during', 'my'): 1
# ('during', 'my', 'b.tech'): 1
# ('my', 'b.tech', 'course.'): 1
# ('b.tech', 'course.', 'i'): 1
# ('course.', 'i', 'completed'): 1
# ('i', 'completed', 'my'): 1
# ('completed', 'my', 'intermediate'): 1
# ('my', 'intermediate', 'education'): 1
# ('intermediate', 'education', 'in'): 1
# ('education', 'in', 'mpc'): 1
# ('in', 'mpc', 'with'): 1
# ('mpc', 'with', 'strong'): 1
# ('with', 'strong', 'interest'): 1
# ('strong', 'interest', 'in'): 1
# ('interest', 'in', 'mathematics.'): 1
# ('in', 'mathematics.', 'i'): 1
# ('mathematics.', 'i', 'want'): 1
# ('i', 'want', 'to'): 1
# ('want', 'to', 'become'): 1
# ('to', 'become', 'a'): 1
# ('become', 'a', 'software'): 1
# ('a', 'software', 'engineer'): 1
# ('software', 'engineer', 'and'): 1
# ('engineer', 'and', 'build'): 1
# ('and', 'build', 'innovative'): 1
# ('build', 'innovative', 'technology'): 1
# ('innovative', 'technology', 'solutions.'): 1
# ('technology', 'solutions.', 'i'): 1
# ('solutions.', 'i', 'am'): 1
# ('i', 'am', 'improving'): 1
# ('am', 'improving', 'my'): 1
# ('improving', 'my', 'coding'): 1
# ('my', 'coding', 'skills'): 1
# ('coding', 'skills', 'by'): 1
# ('skills', 'by', 'practicing'): 1
# ('by', 'practicing', 'problems'): 1
# ('practicing', 'problems', 'every'): 1
# ('problems', 'every', 'day.'): 1
# ('every', 'day.', 'i'): 1
# ('day.', 'i', 'am'): 1
# ('i', 'am', 'exploring'): 1
# ('am', 'exploring', 'artificial'): 1
# ('exploring', 'artificial', 'intelligence'): 1
# ('artificial', 'intelligence', 'and'): 1
# ('intelligence', 'and', 'deep'): 1
# ('and', 'deep', 'learning'): 1
# ('deep', 'learning', 'concepts'): 1
# ('learning', 'concepts', 'in'): 1
# ('concepts', 'in', 'my'): 1
# ('in', 'my', 'studies.'): 1
# ('my', 'studies.', 'i'): 1
# ('studies.', 'i', 'participate'): 1
# ('i', 'participate', 'in'): 1
# ('participate', 'in', 'technical'): 1
# ('in', 'technical', 'workshops'): 1
# ('technical', 'workshops', 'and'): 1
# ('workshops', 'and', 'seminars'): 1
# ('and', 'seminars', 'to'): 1
# ('seminars', 'to', 'enhance'): 1
# ('to', 'enhance', 'my'): 1
# ('enhance', 'my', 'knowledge.'): 1
# ('my', 'knowledge.', 'i'): 1
# ('knowledge.', 'i', 'enjoy'): 1
# ('i', 'enjoy', 'working'): 1
# ('enjoy', 'working', 'on'): 1
# ('working', 'on', 'real-world'): 1
# ('on', 'real-world', 'software'): 1
# ('real-world', 'software', 'development'): 1
# ('software', 'development', 'projects.'): 1
# ('development', 'projects.', 'i'): 1
# ('projects.', 'i', 'aim'): 1
# ('i', 'aim', 'to'): 1
# ('aim', 'to', 'contribute'): 1
# ('to', 'contribute', 'to'): 1
# ('contribute', 'to', 'modern'): 1
# ('to', 'modern', 'technology'): 1
# ('modern', 'technology', 'through'): 1
# ('technology', 'through', 'research'): 1
# ('through', 'research', 'and'): 1
# ('research', 'and', 'innovation.'): 1
# ('and', 'innovation.', 'i'): 1
# ('innovation.', 'i', 'am'): 1
# ('i', 'am', 'preparing'): 1
# ('am', 'preparing', 'for'): 1
# ('preparing', 'for', 'a'): 1
# ('for', 'a', 'successful'): 1
# ('a', 'successful', 'career'): 1
# ('successful', 'career', 'in'): 1
# ('career', 'in', 'the'): 1
# ('in', 'the', 'it'): 1
# ('the', 'it', 'industry.'): 1

# %% [markdown]
# **Next Word Prediction Using Bi-Gram Counts**

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I am"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = " learning programming"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "I want"
next_word4 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word4}'")
# Out:
# probability of  studying is  0.2
# probability of  learning is  0.2
# probability of  improving is  0.2
# probability of  exploring is  0.2
# probability of  preparing is  0.2
# Given sequence: 'I am', predicted next word: 'studying'
# Given sequence: ' learning programming', predicted next word: 'No bigram found starting with 'programming'.'
# probability of  to is  1.0
# Given sequence: 'I want', predicted next word: 'to'

# %% [markdown]
# # **Deployment of Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter texti am
# probability of  studying is  0.2
# probability of  learning is  0.2
# probability of  improving is  0.2
# probability of  exploring is  0.2
# probability of  preparing is  0.2
# Given sequence: 'i am', predicted next word: 'studying'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts**

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "	I am studying"
next_word1 = predict_next_word_trigram(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I completed my"
next_word2 = predict_next_word_trigram(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  b.tech is  1.0
# Given sequence: '	I am studying', predicted next word: 'b.tech'
# probability of  intermediate is  1.0
# Given sequence: 'I completed my', predicted next word: 'intermediate'

# %% [markdown]
# # **Deployment of Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter texti want to
# probability of  become is  1.0
# Given sequence: 'i want to', predicted next word: 'become'

# %% [markdown]
# # **Next Word Prediction Using Bi-Gram Counts with Laplace Smoothening**

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I participate"
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "I aim "
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")
# Out:
# probability of studying is  0.024691358024691357
# probability of learning is  0.024691358024691357
# probability of improving is  0.024691358024691357
# probability of exploring is  0.024691358024691357
# probability of preparing is  0.024691358024691357
# Given sequence: 'I am', predicted next word: 'studying'
# probability of in is  0.025974025974025976
# Given sequence: 'I participate', predicted next word: 'in'
# probability of to is  0.025974025974025976
# Given sequence: 'I aim ', predicted next word: 'to'

# %% [markdown]
# # **Deployment of Laplace Smoothening based Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter texti aim
# probability of to is  0.025974025974025976
# Given sequence: 'i aim', predicted next word: 'to'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts based on laplace smoothening**

# %%
def predict_next_word_trigram_Laplace(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+1) / (last_two_words_bigram_count+V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am preparing"
next_word1 = predict_next_word_trigram_Laplace(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = " my coding skills"
next_word2 = predict_next_word_trigram_Laplace(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  for is  0.025974025974025976
# Given sequence: 'I am preparing', predicted next word: 'for'
# probability of  by is  0.025974025974025976
# Given sequence: ' my coding skills', predicted next word: 'by'

# %% [markdown]
# # **Deployment of Laplace Smoothening based Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_Laplace(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textmy coding skills
# probability of  by is  0.025974025974025976
# Given sequence: 'my coding skills', predicted next word: 'by'

# %% [markdown]
# # **Next Word Prediction Using Bi-Gram Counts with Add - K Smoothening**

# %%
def predict_next_word_bigram_K(word_sequence, bigram_counts, unigram_counts, K): #K=0.5-0.01
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+K) / (last_word_unigram_count+K*V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am"
next_word1 = predict_next_word_bigram_K(sequence1, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I enjoy"
next_word2 = predict_next_word_bigram_K(sequence2, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = " technical workshops"
next_word3 = predict_next_word_bigram_K(sequence3, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")
# Out:
# probability of studying is  0.03488372093023256
# probability of learning is  0.03488372093023256
# probability of improving is  0.03488372093023256
# probability of exploring is  0.03488372093023256
# probability of preparing is  0.03488372093023256
# Given sequence: 'I am', predicted next word: 'studying'
# probability of working is  0.038461538461538464
# Given sequence: 'I enjoy', predicted next word: 'working'
# probability of and is  0.038461538461538464
# Given sequence: ' technical workshops', predicted next word: 'and'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_K(ip_text, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter texti am
# probability of studying is  0.03488372093023256
# probability of learning is  0.03488372093023256
# probability of improving is  0.03488372093023256
# probability of exploring is  0.03488372093023256
# probability of preparing is  0.03488372093023256
# Given sequence: 'i am', predicted next word: 'studying'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts with Add - K Smoothening**

# %%
def predict_next_word_trigram_K(word_sequence, Trigrams_counts, bigram_counts,K): #K=0.5-0.01
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+K) / (last_two_words_bigram_count+K*V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am working"
next_word1 = predict_next_word_trigram_K(sequence1, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I am exploring"
next_word2 = predict_next_word_trigram_K(sequence2, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# Given sequence: 'I am working', predicted next word: 'No trigram found starting with 'am working'.'
# probability of  artificial is  0.038461538461538464
# Given sequence: 'I am exploring', predicted next word: 'artificial'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_K(ip_text, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter texti am exploring
# probability of  artificial is  0.038461538461538464
# Given sequence: 'i am exploring', predicted next word: 'artificial'
